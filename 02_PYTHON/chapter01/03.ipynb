# %% [markdown]
# #1장 3강

# %%
print("hello")

# %%
print("world")

# %%
print("everyone")
# Out:
# everyone

# %%
money= 5000

# %%
money= money + 2000
print(money)
# Out:
# 7000

# %%
money
# Out:
# 7000
