# %%
x = 5000
x
# Out:
# 5000

# %%
id(x)
# Out:
# 2528250452816

# %%
y = x
y
# Out:
# 5000

# %%
id(y)
# Out:
# 2528250452816

# %%
x = 500
id(x)
# Out:
# 2528250454416

# %%
x = 600
id(x)
# Out:
# 2528250454064

# %%
a = 10
id(a)
# Out:
# 140711903499464

# %%
a = 20
id(a)
# Out:
# 140711903499784

# %%
a = 10
id(a)
# Out:
# 140711903499464

# %%
number_of_student = 100

# %%
type(number_of_student)
# Out:
# int

# %%
pi = 3.14
type(pi)
# Out:
# float

# %%
result = True
type(result)
# Out:
# bool

# %%
pi = "원주율"
type(pi)
# Out:
# str
