# %% [markdown]
# 2장 4강 : 문자열 형식화

# %% [markdown]
# 1. 1세대: % 연산자 방식

# %% [markdown]
# - %s: 문자열 대체
#     - %숫자s -> 숫자만큼 스페이스 생성
#
# - %d: 정수 대체
#     - %대체문자숫자s -> %5s -> 남는 공백만큼 0 생성
# - %f: 실수 대체
#     - %.nf : 소수점 n자리까지 표시

# %%
message = "나의 이름은 %10s이고, 나이는 %d입니다."

message % ("철수", 20)
# Out:
# '나의 이름은         철수이고, 나이는 20입니다.'

# %%
message = "주문번호: %05d" % 10
message
# Out:
# '주문번호: 00010'

# %%
# message = "숫자: %f" % 10.123456789
# message = "숫자: %.2f" % 10.123456789
# message = "숫자: %10.2f" % 10.123456789
message = "숫자: %010.2f" % 10.123456789
message
# Out:
# '숫자: 0000010.12'

# %%
message = "숫자: %d" % 10.12345
message
# Out:
# '숫자: 10'

# %%
message = "숫자: %s" % 10.12345
message
# 실순지 정순지 모르겠으면 그냥 %s 쓰면 된다.
# Out:
# '숫자: 10.12345'

# %% [markdown]
# 2. 2세대: str.format() 메서드 방식

# %%
- 순서 지정 교체: {0}  {1}  {2}
- 단어 지정 교체: {단어} {단어}

# %%
#message = "내 이름은 {0}이고, 나이는 {1}입니다"
message = "내 이름은 {1}이고, 나이는 {0}입니다"

message.format("철수", 20)
# Out:
# '내 이름은 20이고, 나이는 철수입니다'

# %%
message = "내 이름은 {name}이고, 나이는 {age}입니다."
message.format(name="철수",age=20)
# Out:
# '내 이름은 철수이고, 나이는 20입니다.'

# %%
message = "내 이름은 {name}이고, 나이는 {0}입니다."
message.format(20, name="철수")
# Out:
# '내 이름은 철수이고, 나이는 20입니다.'

# %% [markdown]
# 3. 3세대: f-string 방식

# %%
name = "영희"
age = 20

message = f"내 이름은 {name}이고, 나이는 {age}입니다."
message
# Out:
# '내 이름은 영희이고, 나이는 20입니다.'

# %%
price = 10000

f"가격: {price:,}원"
# Out:
# '가격: 10,000원'

# %%
f"가격: {price:>10,}원"
# Out:
# '가격:     10,000원'

# %%
f"가격: {price:<10,}원"
# Out:
# '가격: 10,000    원'

# %%
# 디버깅 조절자(=)

f"{price=}"
# Out:
# 'price=10000'

# %%
name = "ohmyeongseok"
name
# Out:
# 'ohmyeongseok'

# %%
age = 30
age
# Out:
# 30

# %%
message = "내 나이는 " + str(age) + "살입니다."
message
# Out:
# '내 나이는 30살입니다.'

# %%
result = 10 + 3.14
print(result)
# Out:
# 13.14

# %%
int(result)
# Out:
# 13

# %%
user_input = "25"
if-else(.isdigit(user_input),age=int(user_input),"숫자만 입력해 주세요!")
# Out:
#   Cell In[47], line 2
#     if-else(.isdigit(user_input),age=int(user_input),"숫자만 입력해 주세요!")
#        ^
# SyntaxError: invalid syntax

# %%
count = 10
count *= 5
print(count)
# Out:
# 50

# %%
'apple' < 'banana'
print('apple'<"banana")
# Out:
# True

# %%
menu_name = "Americano"
menu_price = 4500
print("상품:%s|가격:%d원" % (menu_name, menu_price))
# Out:
# 상품:Americano|가격:4500원

# %%
print(f"상품:{menu_name:}|가격:{menu_price:}원")
# Out:
# 상품:Americano|가격:4500원

# %%
price = 10000

f"가격: {price:,}원"
# Out:
# '가격: 10,000원'

# %%
price = 15000

f"금액: {price:>8,}원"
# Out:
# '금액:   15,000원'

# %%
price = 15000
f"금액:{price:>8}원"
# Out:
# '금액:   15000원'

# %%
current_status = "정산 진행중"
price = 6500
f"디버깅 로그 -> {current_status=}, {price=}"
# Out:
# "디버깅 로그 -> current_status='정산 진행중', price=6500"
