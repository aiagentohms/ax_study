# %%
current_temp = 25
if current_temp >= 30:
    print("폭염 주의보가 발령되었습니다.")
else:
    print("쾌적한 날씨입니다.")
# Out:
# 쾌적한 날씨입니다.

# %%
weight = 10
if weight > 23:
    print("대형 수하물 대상입니다. 추가 요금이 부과됩니다.")
elif weight > 15:
    print("일반 위탁 수하물 대상입니다")
else:
    print("무료 수하물 대상입니다.")
# Out:
# 무료 수하물 대상입니다.

# %%
age = 14
height = 129
if age >= 12 and height >= 130:
    print("탑승 가능합니다. 관리자 확인을 진행하십시오")
else: 
    print("탑승 요건을 만족하지 못했습니다.")
# Out:
# 탑승 요건을 만족하지 못했습니다.

# %%
for i in range(1,5):
    print(f"{i}번째 고객님 입니다.")
# Out:
# 1번째 고객님 입니다.
# 2번째 고객님 입니다.
# 3번째 고객님 입니다.
# 4번째 고객님 입니다.

# %%
battery_status = 80
while battery_status <= 100:
    print(f"현재 배터리: {battery_status}")
    battery_status += 5
# Out:
# 현재 배터리: 80
# 현재 배터리: 85
# 현재 배터리: 90
# 현재 배터리: 95
# 현재 배터리: 100

# %%
for floor in range(1, 3):
    for room in range(1, 4):
        print(f"{floor}층 {room}호")
# Out:
# 1층 1호
# 1층 2호
# 1층 3호
# 2층 1호
# 2층 2호
# 2층 3호

# %%
order_database = [
    {"name": "김철수", "completed": True, "price": 60000},
    {"name": "이영희", "completed": False, "price": 35000},
    {"name": "박민수", "completed": True, "price": 25000},
    {"name": "최지영", "completed": True, "price": 85000},
    {"name": "정성민", "completed": False, "price": 90000}
]

amount_price = 0
num_of_order = 0

for user in order_database:
    if user["completed"]:
        num_of_order += 1
        if user["price"] >= 50000:
            amount_price += user["price"]
print(f"우수 고객 주문 건수: {num_of_order}건")
print(f"우수 고객 총 결제 금액: {amount_price}원")
# Out:
# 우수 고객 주문 건수: 3건
# 우수 고객 총 결제 금액: 145000원

# %%
fruit_sweetness = [12.5, 14.2, 11.8, 10.5, 15.0, 13.6, 11.2, 14.8, 12.0, 13.1]

max = fruit_sweetness[0]
min = fruit_sweetness[0]
total = 0
for max in fruit_sweetness:
    if
# Out:
#   Cell In[1], line 7
#     if
#        ^
# SyntaxError: invalid syntax

# %%
# 1부터 6까지의 정수 중 하나 뽑기 (1과 6 포함)
dice = random.randint(1,6)
print(f"주사위 결과: {dice}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 1부터 6까지의 정수 중 하나 뽑기 (1과 6 포함)
# ----> 2 dice = random.randint(1,6)
#       3 print(f"주사위 결과: {dice}")
#
# NameError: name 'random' is not defined

# %%
def cal(x):
    y = x*2 + 1
    return y

# %%
cal(5)
# Out:
# 11

# %%
def form(x):
    y = x - 2
    return y

# %%
form(1)
# Out:
# -1

# %%
def jdg(x):
    y = x - 2
    return y

# %%
jdg(4)
# Out:
# 2
