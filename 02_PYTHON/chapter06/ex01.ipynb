# %%
songs = ["Don't stop it now", "Bohemian Rhapsody", "Radio gaga"]
songs_iterator = iter(songs)

# %%
print(next(songs_iterator))
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 print(next(songs_iterator))
#
# StopIteration:

# %%
def cheer_up():
    print("대박")
    yield

    print("사건")
    yield

    print("성공")
    yield

# %%
gen = cheer_up()
gen
# Out:
# <generator object cheer_up at 0x000001BD32BD5780>

# %%
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 next(gen)
#
# StopIteration:

# %%
import sys

list_comprehension = [num ** 2 for num in range(50000)]

generator_expression = (num ** 2 for num in range(50000))

list_size = sys.getsizeof(list_comprehension)
gen_size = sys.getsizeof(generator_expression)

# %%
print(f"리스트 컴프리헨션 메모리 용량: {list_size} 바이트")
print(f"제너레이터 표현식 메모리 용량: {gen_size} 바이트")
# Out:
# 리스트 컴프리헨션 메모리 용량: 444376 바이트
# 제너레이터 표현식 메모리 용량: 200 바이트

# %%
import random

# %%
dice = random.randint(1, 6)

# %%
print(f"출력된 숫자: {dice}")
# Out:
# 출력된 숫자: 4

# %%
import datetime

# %%
now = datetime.datetime.now()

# %%
now_time = now.strftime("%Y-%M-%D %H:%m:%S")

# %%
print(now_time)
# Out:
# 2026-08-08/14/26 17:08:46

# %%
import datetime as dt
dt.datetime.now()
sigan = dt.datetime.now()
print(sigan.strftime("%H:%m:%S"))
# Out:
# 17:08:07
