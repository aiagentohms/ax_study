# %%
menu = ['피자', '치킨', '햄버거', '파스타']
import random

print(random.choice(menu))

print(random.randint(1,100))
# Out:
# 파스타
# 86

# %%
import datetime
now = datetime.datetime.now()
now.strftime("%H시 %M분 %S초")
# now.strftime(f"{%H}시 {%M}분 {%S}초")
# Out:
# '17시 25분 09초'

# %%
import json
content = {
    "도서명": "파이썬기초",
    "저자": "팀스파르타",
    "가격": "30000"
}

look = json.dumps(content, ensure_ascii=False)
print(look)
type(look)
# Out:
# {"도서명": "파이썬기초", "저자": "팀스파르타", "가격": "30000"}
# str
