# %%
age = 25

print(isinstance(age, int))

esse = [True, True, True]

print(all(esse))
# Out:
# True
# True

# %%
score = [85, 62, 92, 78, 55]

print(round((sum(score) / len(score)), 1))



over70 = list(filter(lambda x: x >= 70, score))

print(over70)
# Out:
# 74.4
# [85, 92, 78]

# %%
names = ["이민서", "박준형"]
emails = ["minseo@ssu.ac.kr", "junhyung@daum.net"]
items = zip(names, emails)

for idx, (name, email) in enumerate(items, start=1):
    print(f"{idx}번 당첨자: {name}|이메일: {email}")
# Out:
# 1번 당첨자: 이민서|이메일: minseo@ssu.ac.kr
# 2번 당첨자: 박준형|이메일: junhyung@daum.net
