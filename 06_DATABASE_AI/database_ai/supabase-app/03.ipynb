# %% [markdown]
# # 3장 2강: SDK 개발 환경 구성과 연결 테스트
# ## 3. Supabase Client 초기화

# %%
import os
from supabase import create_client

url = os.getenv("SUPABASE_URL")
key = os.getenv("SUPABASE_PUBLISHABLE_KEY")

# .env 파일의 값을 환경변수로 불러오기


# Client 초기화
supabase = create_client(url, key)

print(supabase)
# Out:
# <supabase._sync.client.Client object at 0x00000171755F78C0>

# %% [markdown]
# ## 4. 연결 테스트와 응답·오류 객체 확인

# %% [markdown]
# # 3장 3강: SDK 기반 데이터 생성 구현

# %% [markdown]
# ## 1. SDK insert 구조

# %%
# 사용자 추가
response = supabase.table("users").insert({"email":"user03@test.org"}).execute()

# %%
response.data
# Out:
# [{'id': '88b450e9-24f3-4a57-8106-21810ce8fc84',
#   'email': 'user03@test.org',
#   'created_at': '2026-09-09T01:55:08.063698'}]

# %%
# documents에 추가
response = supabase.table("documents").insert({
    "title": "첫 번째 문서",
    "content": "본문 내용",
    "user_id": "88b450e9-24f3-4a57-8106-21810ce8fc84"
}).execute()

response.data
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[9], line 6
#       2 response = supabase.table("documents").insert({
#       3     "title": "첫 번째 문서",
#       4     "content": "본문 내용",
#       5     "user_id": "88b450e9-24f3-4a57-8106-21810ce8fc84"
# ----> 6 }).execute()
#       7
#       8 response.data
#
# File ~\Documents\ax_study\06_DATABASE_AI\database_ai\.venv\Lib\site-packages\postgrest\_sync\request_builder.py:96, in SyncQueryRequestBuilder.execute(self)
#      94     else:
#      95         json_obj = model_validate_json(APIErrorFromJSON, r.content)
# ---> 96         raise APIError(dict(json_obj))
#      97 except ValidationError as e:
#      98     raise APIError(generate_default_error_message(r))
#
# APIError: {'message': "Could not find the 'user_id' column of 'documents' in the schema cache", 'code': 'PGRST204', 'hint': None, 'details': None}

# %%
# 회원 목록 조회
response = supabase.table("users").select("*").execute()

response.data
# Out:
# [{'id': 'eed69d44-602b-48d7-8f15-3da8d1a1864b',
#   'email': 'user01@test.org',
#   'created_at': '2026-09-08T03:00:58.966989'},
#  {'id': '93c5b061-9ee1-471a-92a9-65e1ebca8c9c',
#   'email': 'user02@test.org',
#   'created_at': '2026-09-09T00:42:36.752433'},
#  {'id': '88b450e9-24f3-4a57-8106-21810ce8fc84',
#   'email': 'user03@test.org',
#   'created_at': '2026-09-09T01:55:08.063698'}]

# %%
response = (
    supabase.table("users")
        .select("*")
        .ilike("emeil", "user02%")
        .single() # fpzhem 1ro
        .execute()
        )

print(response.data)
# id, email, created_at = response.data[0]

# print(f"id:{id}, email:{email}, created_at:{created_at}")
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[15], line 6
#       2     supabase.table("users")
#       3         .select("*")
#       4         .ilike("emeil", "user02%")
#       5         .single() # fpzhem 1ro
# ----> 6         .execute()
#       7         )
#       8
#       9 print(response.data)
#
# File ~\Documents\ax_study\06_DATABASE_AI\database_ai\.venv\Lib\site-packages\postgrest\_sync\request_builder.py:129, in SyncSingleRequestBuilder.execute(self)
#     127     else:
#     128         json_obj = model_validate_json(APIErrorFromJSON, r.content)
# --> 129         raise APIError(dict(json_obj))
#     130 except ValidationError as e:
#     131     raise APIError(generate_default_error_message(r))
#
# APIError: {'message': 'column users.emeil does not exist', 'code': '42703', 'hint': 'Perhaps you meant to reference the column "users.email".', 'details': None}

# %%
response = (
    supabase.table("users")
        .select("*")
        .ilike("emeil", "user02%")
        .maybe_single() # 0~1, 0개이면 None
        .limit(1)
        .execute()
        )

print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 6
#       2     supabase.table("users")
#       3         .select("*")
#       4         .ilike("emeil", "user02%")
#       5         .maybe_single() # 0~1, 0개이면 None
# ----> 6         .limit(1)
#       7         .execute()
#       8         )
#       9
#
# AttributeError: 'SyncMaybeSingleRequestBuilder' object has no attribute 'limit'

# %% [markdown]
# ## 2. 입력값과 DB 컬럼 매핑

# %% [markdown]
# ## 3. 생성 결과와 오류 응답 처리

# %%
create_document(None, "본문 내용입니다.", 1)

# %% [markdown]
# # 3장 4강: SDK 기반 데이터 조회 구현

# %% [markdown]
# ## 1. SDK select 구조

# %% [markdown]
# ## 2. 조건 필터링: eq, order, limit

# %% [markdown]
# ## 3. 사용자별 조회와 결과 리스트 처리

# %% [markdown]
# # 3장 5강: SDK 기반 데이터 수정·삭제 구현

# %% [markdown]
# ## 1. SDK update 구조

# %% [markdown]
# ## 2. SDK delete 구조

# %% [markdown]
# ## 3. 수정·삭제 후 검증과 오류 처리

# %%
# 검증: 상태가 잘 바뀌었는지 다시 조회

# %% [markdown]
# # 3장 6강: Supabase Authentication 기본 흐름

# %% [markdown]
# ## 2. 이메일 기반 회원가입과 로그인

# %%
# 로그인

# %% [markdown]
# ## 3. 세션, 로그아웃, user 객체

# %%
# 현재 로그인된 사용자 확인

# %%
# 로그아웃

# %% [markdown]
# ## 4. 사용자 ID와 테이블 데이터 연결

# %% [markdown]
# # 3장 7강: 사용자별 데이터 접근과 권한 관리

# %% [markdown]
# ## 2. user_id 기반 필터링

# %%
# 본인 문서만 조회

# %% [markdown]
# # 3장 8강: SDK 기반 미니 과제 - 사용자별 문서 CRUD

# %% [markdown]
# ## 2. Auth와 user_id 연결

# %%
# 생성: 로그인 사용자의 문서


# 조회: 본인 문서만

# %% [markdown]
# ## 3. 응답·오류 처리와 코드 구조 정리
