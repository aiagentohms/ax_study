# %%
from supabase import create_client

url = "https://ptzztmdhgwizthbiotgt.supabase.co"
key = "sb_publishable_SrXhb5Z7YQqP_JaPyrsWvA_iEPqeneg"

supabase = create_client(url, key)

response = supabase.table("users").select("*").execute()
print(response.data)
# Out:
# [{'id': 'eed69d44-602b-48d7-8f15-3da8d1a1864b', 'email': 'user01@test.org', 'created_at': '2026-09-08T03:00:58.966989'}, {'id': '93c5b061-9ee1-471a-92a9-65e1ebca8c9c', 'email': 'user02@test.org', 'created_at': '2026-09-09T00:42:36.752433'}, {'id': '88b450e9-24f3-4a57-8106-21810ce8fc84', 'email': 'user03@test.org', 'created_at': '2026-09-09T01:55:08.063698'}]

# %%
id, email, created_at = response.data[0]

# %%
response.data[1]
# Out:
# {'id': '93c5b061-9ee1-471a-92a9-65e1ebca8c9c',
#  'email': 'user02@test.org',
#  'created_at': '2026-09-09T00:42:36.752433'}

# %%
response.data[2]
# Out:
# {'id': '88b450e9-24f3-4a57-8106-21810ce8fc84',
#  'email': 'user03@test.org',
#  'created_at': '2026-09-09T01:55:08.063698'}

# %%
import os
from dotenv import load_dotenv
from supabase import create_client

load_dotenv()

url = os.getenv("SUPABASE_URL")
key = os.getenv("SUPABASE_PUBLISHABLE_KEY")

supabase = create_client(url, key)
